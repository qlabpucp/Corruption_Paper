# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.ticker import MaxNLocator

# %% [markdown]
# ## 1. Caso 1

# %% [markdown]
# ### 1.1. Corrupción intensa

# %%
data = pd.read_stata( r'../../input/built_data/c1.dta' )

data[ 'ci_count' ] = data[ 'corrup_intensa' ].map( { 'Sí': 1, 'No': 0 } ).astype( int )

data = data [data[ 'year' ] <= 2020 ]

# Group by 'year' and sum the 'ci_count' values
data = data.groupby('year')[ 'ci_count' ].sum()

sns.set_theme(style = 'white' )
fig, ax = plt.subplots( figsize = ( 10, 6 ) )

data.plot( kind  = 'bar', 
           ax    = ax, 
           width = 0.8, 
           color = 'slategray' )

ax.set_title( 'Number of municipalities where at least once case of \nsevere corruption ocurred per year',
              fontsize   = 16,
              fontweight = 'bold' )
ax.set_xlabel( 'Start year of the criminal event',
               fontsize = 12 )
ax.set_ylabel( 'Number of municipalities',
               fontsize = 12 )

for p in ax.patches:
    ax.annotate( str( p.get_height() ), ( p.get_x() + p.get_width() / 2, p.get_height() ),
                ha       = 'center',
                va       = 'bottom',
                fontsize = 12 )

plt.savefig(r'../../extra/graphs/numero_c1_ci.jpg',
            dpi = 300,
            bbox_inches = 'tight')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 1.3. Corrupción amplia

# %%
data = pd.read_stata( r'../../input/built_data/c1.dta' )

data[ 'ca_count' ] = data[ 'corrup_amplia' ].map( { 'Sí': 1, 'No': 0 } ).astype( int )

data = data [data[ 'year' ] <= 2020 ]

# Group by 'year' and sum the 'ci_count' values
data = data.groupby('year')[ 'ca_count' ].sum()

sns.set_theme(style = 'white' )
fig, ax = plt.subplots( figsize = ( 10, 6 ) )

data.plot( kind  = 'bar', 
           ax    = ax, 
           width = 0.8, 
           color = 'rosybrown' )

ax.set_title( 'Number of municipalities where at least once case of \nbroad corruption ocurred per year',
              fontsize   = 16,
              fontweight = 'bold' )
ax.set_xlabel( 'Start year of the criminal event',
               fontsize = 12 )
ax.set_ylabel( 'Number of municipalities',
               fontsize = 12 )

for p in ax.patches:
    ax.annotate( str( p.get_height() ), ( p.get_x() + p.get_width() / 2, p.get_height() ),
                ha       = 'center',
                va       = 'bottom',
                fontsize = 12 )

plt.savefig(r'../../extra/graphs/numero_c1_ca.jpg',
            dpi = 300,
            bbox_inches = 'tight')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2. Caso 2

# %% [markdown]
# ### 1.1. Corrupción intensa

# %%
data = pd.read_stata( r'../../input/built_data/c2.dta' )

data[ 'ci_count' ] = data[ 'corrup_intensa' ].map( { 'Sí': 1, 'No': 0 } ).astype( int )

data = data [data[ 'year' ] <= 2020 ]

# Group by 'year' and sum the 'ci_count' values
data = data.groupby('year')[ 'ci_count' ].sum()

sns.set_theme(style = 'white' )
fig, ax = plt.subplots( figsize = ( 10, 6 ) )

data.plot( kind  = 'bar', 
           ax    = ax, 
           width = 0.8, 
           color = 'slategray' )

ax.set_title( 'Number of cases of severe corruption per year',
              fontsize   = 16,
              fontweight = 'bold' )
ax.set_xlabel( 'Start year of the criminal event',
               fontsize = 12 )
ax.set_ylabel( 'Number of cases of severe corruption',
               fontsize = 12 )

for p in ax.patches:
    ax.annotate( str( p.get_height() ), ( p.get_x() + p.get_width() / 2, p.get_height() ),
                ha       = 'center',
                va       = 'bottom',
                fontsize = 12 )

plt.savefig(r'../../extra/graphs/numero_c2_ci.jpg',
            dpi = 300,
            bbox_inches = 'tight')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 1.3. Corrupción amplia

# %%
data = pd.read_stata( r'../../input/built_data/c2.dta' )

data[ 'ca_count' ] = data[ 'corrup_amplia' ].map( { 'Sí': 1, 'No': 0 } ).astype( int )

data = data [data[ 'year' ] <= 2020 ]

# Group by 'year' and sum the 'ci_count' values
data = data.groupby('year')[ 'ca_count' ].sum()

sns.set_theme(style = 'white' )
fig, ax = plt.subplots( figsize = ( 10, 6 ) )

data.plot( kind  = 'bar', 
           ax    = ax, 
           width = 0.8, 
           color = 'rosybrown' )

ax.set_title( 'Number of cases of broad corruption per year',
              fontsize   = 16,
              fontweight = 'bold' )
ax.set_xlabel( 'Start year of the criminal event',
               fontsize = 12 )
ax.set_ylabel( 'Number of cases of broad corruption',
               fontsize = 12 )

for p in ax.patches:
    ax.annotate( str( p.get_height() ), ( p.get_x() + p.get_width() / 2, p.get_height() ),
                ha       = 'center',
                va       = 'bottom',
                fontsize = 12 )

plt.savefig(r'../../extra/graphs/numero_c2_ca.jpg',
            dpi = 300,
            bbox_inches = 'tight')

plt.tight_layout()
plt.show()

# %%
# ANTIGUO GRÁFICO CON DOS CATEGORÍAS PARA LA BASE 

# data = pd.read_stata( r'../../input/built_data/c1.dta' )

# data[ 'ci_count' ] = data[ 'corrup_intensa' ].map( { 'Sí': 1, 'No': 0 } )
# data[ 'ci_count' ] = data[ 'ci_count' ].astype( str ).astype( int )

# data[ 'ca_count' ] = data[ 'corrup_amplia' ].map( { 'Sí': 1, 'No': 0 } )
# data[ 'ca_count' ] = data[ 'ca_count' ].astype( str ).astype( int )

# data               = data[ data[ 'year' ] <= 2020 ]

# data = data[ [ 'ci_count', 'ca_count', 'year' ] ]

# data = data.groupby( 'year' )[ [ 'ci_count', 'ca_count' ] ].sum()

# sns.set_theme(style = 'white' )
# fig, ax = plt.subplots( figsize = ( 10, 6 ) )
# data.plot( kind = 'bar', ax = ax, width = 0.8 )

# ax.set_title(  'Número de actos de corrupción según tipo, por ubigeo y año (Caso 1)', 
#                fontsize = 16 )
# ax.set_xlabel( 'Año de inicio del evento delictivo', 
#                fontsize = 12 )
# ax.set_ylabel( 'Número de actos de corrupción', 
#                fontsize = 12 )
# ax.legend( [ 'Corrupción intensa', 'Corrupción amplia' ] )

# for p in ax.patches:
#     ax.annotate( str( p.get_height() ), ( p.get_x() + p.get_width() / 2, p.get_height() ), 
#                 ha       = 'center', 
#                 va       = 'bottom',
#                 fontsize = 9.5 )

# plt.savefig( r'../../extra/graphs/numero_c1.jpg' , 
#          dpi         = 300, 
#          bbox_inches = 'tight' )
    
# plt.tight_layout()
# plt.show()
